# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Create a line chart
plt.plot(x, y, marker='o', linestyle='-')

# Add labels and title
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Line Chart Example')

# Add grid
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Example data
students = ['Student 1', 'Student 2', 'Student 3', 'Student 4', 'Student 5']
scores = [76, 88, 96, 90, 98]

# Create the bar chart
plt.bar(students, scores, color='skyblue')

# Add labels and title
plt.xlabel('Students')
plt.ylabel('Exam Scores')
plt.title('Exam Scores of Students')

# Show the chart
plt.show()

# %%
import matplotlib.pyplot as plt

# Data to plot
labels = ['Python', 'Java', 'JavaScript', 'C#', 'C++']
sizes = [40, 25, 15, 10, 10]  # Sizes in percentage
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightpink']
explode = (0.1, 0, 0, 0, 0)  # explode the 1st slice (Python)

# Plot
plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Programming Languages Usage')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = np.sin(x) * np.cos(y)

# Plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, cmap='coolwarm')

# Customize labels and title
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
ax.set_title('3D Plot of sin(x) * cos(y)')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating data
np.random.seed(10)
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# Plot
plt.figure(figsize=(10, 6))
plt.boxplot(data, patch_artist=True)

# Customize labels and title
plt.xticks(ticks=np.arange(1, 4), labels=['A', 'B', 'C'])
plt.xlabel('Groups')
plt.ylabel('Values')
plt.title('Box Plot')

plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generating data
np.random.seed(0)
data = np.random.rand(10, 10)

# Plot
plt.figure(figsize=(8, 6))
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.colorbar(label='Intensity')

# Customize labels and title
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('2D Heatmap')

plt.show()

# %%
import matplotlib.pyplot as plt

# Data
categories = ['A', 'B', 'C', 'D', 'E']
values1 = [20, 35, 30, 35, 27]
values2 = [25, 32, 34, 20, 25]

# Plot
plt.figure(figsize=(8, 6))
plt.bar(categories, values1, label='Group 1')
plt.bar(categories, values2, bottom=values1, label='Group 2')

# Customize labels and title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Stacked Bar Chart')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Task data
tasks = ['Task 1', 'Task 2', 'Task 3', 'Task 4']
start_dates = ['2024-04-01', '2024-04-05', '2024-04-10', '2024-04-15']
end_dates = ['2024-04-04', '2024-04-09', '2024-04-14', '2024-04-20']

# Convert dates to datetime objects
start_dates = [mdates.datestr2num(date) for date in start_dates]
end_dates = [mdates.datestr2num(date) for date in end_dates]

# Plot
fig, ax = plt.subplots(figsize=(10, 6))

for i, task in enumerate(tasks):
    ax.barh(task, end_dates[i] - start_dates[i], left=start_dates[i], height=0.5, align='center', alpha=0.8)

# Customize labels and title
ax.xaxis_date()
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.set_xlabel('Date')
ax.set_ylabel('Tasks')
ax.set_title('Gantt Chart')

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
theta = np.linspace(0, 2*np.pi, 100)
r = np.sin(3*theta)

# Plot
plt.figure(figsize=(8
                    , 6))
plt.polar(theta, r)

# Customize title
plt.title('Polar Plot')

plt.show()
